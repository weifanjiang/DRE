# %% [markdown]
# # DEMO

# %%
import pickle
import pandas

# %%
with open('data/scout/scout_unstructured_reduction/one_hop/ColSampling_None_col-0.2-smf-fbs_sec1.pickle', 'rb') as fin:
    train_df, test_df = pickle.load(fin)

# %%
train_df.shape
# Out:
# (48, 50)

# %%
test_df.shape
# Out:
# (43, 50)

# %%
train_df.head()
# Out:
#    IncidentId      EntityType Tier  SnmpCpu_mv  DupManagementIP_pers_1h  \
# 0          21          switch   t1    0.406204                 0.787265
# 1          21  cluster_switch   t1    0.416177                 0.844175
# 2          21      tor_switch   t0    0.878232                 0.940192
# 3          21  cluster_switch   t0    0.734764                 0.679455
# 4          21      tor_switch   t0    0.456479                 0.784217
#
#    NGSvsLLDPt1t2_pers_1h  NetscanBadDevice_mv  LinkStatus_pers_1h  \
# 0               0.842132             0.385887            0.959180
# 1               0.155153             0.261772            0.079062
# 2               0.196678             0.099732            0.987441
# 3               0.811512             0.713795            0.602539
# 4               0.165622             0.817866            0.440073
#
#    PhynetInterfaceErrorsPercentageThreshold_mv  MgmtInterfaceFlaps_mv  ...  \
# 0                                     0.257290               0.399317  ...
# 1                                     0.189264               0.821606  ...
# 2                                     0.255873               0.896018  ...
# 3                                     0.465431               0.997561  ...
# 4                                     0.691921               0.877578  ...
#
#    NGSvsMSAssetName_pers_1h  SnmpLoopbackReachability_mv  DupManagementIP_mv  \
# 0                  0.517892                     0.126203            0.205123
# 1                  0.445054                     0.462729            0.701938
# 2                  0.653824                     0.646398            0.390633
# 3                  0.768746                     0.618772            0.621393
# 4                  0.445670                     0.043069            0.318874
#
#    SONiCSNMPHighCPU_pers_1h  Hw3Drop_pers_1h  DeviceReload_mv  BGPDown_mv  \
# 0                  0.872940         0.560198         0.960294    0.651774
# 1                  0.503650         0.617248         0.306044    0.467204
# 2                  0.898663         0.430019         0.108546    0.539704
# 3                  0.032112         0.715286         0.159636    0.229793
# 4                  0.045824         0.725609         0.389932    0.589048
#
#    NetscanPayloadPaths_mv  MaxprefixThr_mv  MaxprefixExceeded_mv
# 0                0.061515         0.354703              0.210518
# 1                0.496758         0.840858              0.523888
# 2                0.671822         0.503002              0.000472
# 3                0.224848         0.011164              0.733501
# 4                0.866597         0.585186              0.535746
#
# [5 rows x 50 columns]

# %%
test_df.head()
# Out:
#    IncidentId      EntityType Tier  SnmpCpu_mv  DupManagementIP_pers_1h  \
# 0          21          switch   t1    0.406204                 0.787265
# 1          21  cluster_switch   t1    0.416177                 0.844175
# 2          21      tor_switch   t0    0.878232                 0.940192
# 3          21  cluster_switch   t0    0.734764                 0.679455
# 4          21      tor_switch   t0    0.456479                 0.784217
#
#    NGSvsLLDPt1t2_pers_1h  NetscanBadDevice_mv  LinkStatus_pers_1h  \
# 0               0.842132             0.385887            0.959180
# 1               0.155153             0.261772            0.079062
# 2               0.196678             0.099732            0.987441
# 3               0.811512             0.713795            0.602539
# 4               0.165622             0.817866            0.440073
#
#    PhynetInterfaceErrorsPercentageThreshold_mv  MgmtInterfaceFlaps_mv  ...  \
# 0                                     0.257290               0.399317  ...
# 1                                     0.189264               0.821606  ...
# 2                                     0.255873               0.896018  ...
# 3                                     0.465431               0.997561  ...
# 4                                     0.691921               0.877578  ...
#
#    NGSvsMSAssetName_pers_1h  SnmpLoopbackReachability_mv  DupManagementIP_mv  \
# 0                  0.517892                     0.126203            0.205123
# 1                  0.445054                     0.462729            0.701938
# 2                  0.653824                     0.646398            0.390633
# 3                  0.768746                     0.618772            0.621393
# 4                  0.445670                     0.043069            0.318874
#
#    SONiCSNMPHighCPU_pers_1h  Hw3Drop_pers_1h  DeviceReload_mv  BGPDown_mv  \
# 0                  0.872940         0.560198         0.960294    0.651774
# 1                  0.503650         0.617248         0.306044    0.467204
# 2                  0.898663         0.430019         0.108546    0.539704
# 3                  0.032112         0.715286         0.159636    0.229793
# 4                  0.045824         0.725609         0.389932    0.589048
#
#    NetscanPayloadPaths_mv  MaxprefixThr_mv  MaxprefixExceeded_mv
# 0                0.061515         0.354703              0.210518
# 1                0.496758         0.840858              0.523888
# 2                0.671822         0.503002              0.000472
# 3                0.224848         0.011164              0.733501
# 4                0.866597         0.585186              0.535746
#
# [5 rows x 50 columns]

# %%
train_df.IncidentId.unique()
# Out:
# array([ 21, 441, 399, 329,  44])

# %%
test_df.IncidentId.unique()
# Out:
# array([ 21, 441, 399,  44])
