# %% [markdown]
# # DEMO

# %%
import pickle
import pandas

# %%
with open('data/scout/scout_unstructured_reduction/one_hop/ColSampling_None_col-0.2-smf-fbs_sec1.pickle', 'rb') as fin:
    train_df, test_df = pickle.load(fin)

# %%
train_df.shape
# Out:
# (45, 50)

# %%
test_df.shape
# Out:
# (3, 50)

# %%
train_df.head()
# Out:
#    IncidentId      EntityType Tier  LinkStatus_pers_1h  \
# 0          21          switch   t1            0.959180
# 1          21  cluster_switch   t1            0.079062
# 2          21      tor_switch   t0            0.987441
# 3          21  cluster_switch   t0            0.602539
# 4          21      tor_switch   t0            0.440073
#
#    DupManagementIP_pers_1h  NetscanBadDevice_mv  SnmpCpu_mv  \
# 0                 0.787265             0.385887    0.406204
# 1                 0.844175             0.261772    0.416177
# 2                 0.940192             0.099732    0.878232
# 3                 0.679455             0.713795    0.734764
# 4                 0.784217             0.817866    0.456479
#
#    NGSvsLLDPt1t2_pers_1h  LPMUtilization_pers_1h  NtpError_pers_1h  ...  \
# 0               0.842132                0.923607          0.656550  ...
# 1               0.155153                0.821036          0.951783  ...
# ...

# %%
test_df.head()
# Out:
#    IncidentId  EntityType Tier  LinkStatus_pers_1h  DupManagementIP_pers_1h  \
# 0         399  tor_switch   t0            0.143375                 0.172660
# 1         399      switch   t1            0.086983                 0.233831
# 2         399  tor_switch   t0            0.444291                 0.833838
#
#    NetscanBadDevice_mv  SnmpCpu_mv  NGSvsLLDPt1t2_pers_1h  \
# 0             0.873076    0.927373               0.588789
# 1             0.518633    0.575128               0.770267
# 2             0.028246    0.032275               0.816311
#
#    LPMUtilization_pers_1h  NtpError_pers_1h  ...  QCHardwareDrops_mv  \
# 0                0.339798          0.363081  ...            0.043606
# 1                0.129959          0.613841  ...            0.131529
# 2                0.495935          0.459919  ...            0.003910
#
#    SnmpVoltage_pers_1h  MaxprefixExceeded_mv  ServerTorPktDiscards_pers_1h  \
# ...

# %%
train_df.IncidentId.unique()
# Out:
# array([ 21, 441, 329,  44])

# %%
test_df.IncidentId.unique()
# Out:
# array([399])
